# %%
# !pip install ultralytics

# %%
ROOT_DIR='/content/drive/MyDrive/COCO2014'

# %%
import os
from ultralytics import YOLO
model=YOLO("yolov8.yaml")
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
results=model.train(data=os.path.join(ROOT_DIR,"abcdefg.yaml"), epochs=1)
# Out:
# Ultralytics YOLOv8.0.139 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect predict model="/content/runs/detect/train2/weights/best.pt" source="/content/drive/MyDrive/indoor videos/v6.mp4"
# Out:
# Ultralytics YOLOv8.0.139 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8 summary (fused): 168 layers, 3271907 parameters, 0 gradients
#
# video 1/1 (1/1796) /content/drive/MyDrive/indoor videos/v6.mp4: 640x384 (no detections), 64.9ms
# video 1/1 (2/1796) /content/drive/MyDrive/indoor videos/v6.mp4: 640x384 1 person, 9.0ms
# video 1/1 (3/1796) /content/drive/MyDrive/indoor videos/v6.mp4: 640x384 (no detections), 8.4ms
# video 1/1 (4/1796) /content/drive/MyDrive/indoor videos/v6.mp4: 640x384 (no detections), 13.8ms
# video 1/1 (5/1796) /content/drive/MyDrive/indoor videos/v6.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (6/1796) /content/drive/MyDrive/indoor videos/v6.mp4: 640x384 (no detections), 8.5ms
# video 1/1 (7/1796) /content/drive/MyDrive/indoor videos/v6.mp4: 640x384 (no detections), 9.1ms
# video 1/1 (8/1796) /content/drive/MyDrive/indoor videos/v6.mp4: 640x384 (no detections), 8.3ms
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
