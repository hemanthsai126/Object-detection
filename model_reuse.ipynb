# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.6/607.6 kB 2.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR='/content/gdrive/MyDrive/Final_dataset'

# %%
import os
from ultralytics import YOLO
model=YOLO("yolov8.yaml")
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
results=model.train(data=os.path.join(ROOT_DIR,"google_colab_config.yaml"), epochs=50)
# Out:
# Ultralytics YOLOv8.0.141 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs/detect/train '/content/gdrive/MyDrive/Final_dataset'

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !yolo detect predict model = "/content/runs/detect/train/weights/best.pt" source="/content/gdrive/MyDrive/indoor videos"
# Out:
# Ultralytics YOLOv8.0.141 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8 summary (fused): 168 layers, 3009548 parameters, 0 gradients
#
# video 1/12 (1/1778) /content/gdrive/MyDrive/indoor videos/v1.mp4: 640x384 1 wall, 1 floor, 78.6ms
# video 1/12 (2/1778) /content/gdrive/MyDrive/indoor videos/v1.mp4: 640x384 2 walls, 8.3ms
# video 1/12 (3/1778) /content/gdrive/MyDrive/indoor videos/v1.mp4: 640x384 3 walls, 8.7ms
# video 1/12 (4/1778) /content/gdrive/MyDrive/indoor videos/v1.mp4: 640x384 3 walls, 1 floor, 7.6ms
# video 1/12 (5/1778) /content/gdrive/MyDrive/indoor videos/v1.mp4: 640x384 2 walls, 1 floor, 8.6ms
# video 1/12 (6/1778) /content/gdrive/MyDrive/indoor videos/v1.mp4: 640x384 3 walls, 1 floor, 11.8ms
# video 1/12 (7/1778) /content/gdrive/MyDrive/indoor videos/v1.mp4: 640x384 1 wall, 8.7ms
# video 1/12 (8/1778) /content/gdrive/MyDrive/indoor videos/v1.mp4: 640x384 (no detections), 12.8ms
# ...

# %%
# !yolo detect predict model = "/content/runs/detect/train/weights/best.pt" source="https://www.youtube.com/shorts/ZD-LeGRC1Fg?feature=share"
# Out:
# Ultralytics YOLOv8.0.141 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8 summary (fused): 168 layers, 3009548 parameters, 0 gradients
#
# requirements: Ultralytics requirements ['pafy', 'youtube_dl==2020.12.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 39.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.7s, installed 2 packages: ['pafy', 'youtube_dl==2020.12.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 423, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
# ...

# %%
# !yolo detect predict model = "/content/runs/detect/train/weights/best.pt" source="/content/_Aesthetic_ Home Decorating Ideas For Living Room#aesthetic #homedecor#shorts #asmr#stylish#trending.mp4"
# Out:
# Ultralytics YOLOv8.0.141 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8 summary (fused): 168 layers, 3009548 parameters, 0 gradients
#
# video 1/1 (1/496) /content/_Aesthetic_ Home Decorating Ideas For Living Room#aesthetic #homedecor#shorts #asmr#stylish#trending.mp4: 640x384 3 walls, 87.2ms
# video 1/1 (2/496) /content/_Aesthetic_ Home Decorating Ideas For Living Room#aesthetic #homedecor#shorts #asmr#stylish#trending.mp4: 640x384 3 walls, 6.5ms
# video 1/1 (3/496) /content/_Aesthetic_ Home Decorating Ideas For Living Room#aesthetic #homedecor#shorts #asmr#stylish#trending.mp4: 640x384 4 walls, 7.2ms
# video 1/1 (4/496) /content/_Aesthetic_ Home Decorating Ideas For Living Room#aesthetic #homedecor#shorts #asmr#stylish#trending.mp4: 640x384 4 walls, 6.7ms
# video 1/1 (5/496) /content/_Aesthetic_ Home Decorating Ideas For Living Room#aesthetic #homedecor#shorts #asmr#stylish#trending.mp4: 640x384 4 walls, 6.9ms
# ...

# %%
# !yolo detect predict model = "/content/runs/detect/train/weights/best.pt" source="/content/మా కొత్త ఇంటి Utility Area ఇలా Set చేసా __ Madam Anthe __ Strikers.mp4"
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (8764/13761) /content/మా కొత్త ఇంటి Utility Area ఇలా Set చేసా __ Madam Anthe __ Strikers.mp4: 384x640 2 walls, 6.7ms
# video 1/1 (8765/13761) /content/మా కొత్త ఇంటి Utility Area ఇలా Set చేసా __ Madam Anthe __ Strikers.mp4: 384x640 2 walls, 11.1ms
# video 1/1 (8766/13761) /content/మా కొత్త ఇంటి Utility Area ఇలా Set చేసా __ Madam Anthe __ Strikers.mp4: 384x640 1 wall, 8.3ms
# video 1/1 (8767/13761) /content/మా కొత్త ఇంటి Utility Area ఇలా Set చేసా __ Madam Anthe __ Strikers.mp4: 384x640 1 wall, 6.5ms
# video 1/1 (8768/13761) /content/మా కొత్త ఇంటి Utility Area ఇలా Set చేసా __ Madam Anthe __ Strikers.mp4: 384x640 1 wall, 6.5ms
# video 1/1 (8769/13761) /content/మా కొత్త ఇంటి Utility Area ఇలా Set చేసా __ Madam Anthe __ Strikers.mp4: 384x640 2 walls, 6.5ms
# video 1/1 (8770/13761) /content/మా కొత్త ఇంటి Utility Area ఇలా Set చేసా __ Madam Anthe __ Strikers.mp4: 384x640 2 walls, 6.5ms
# ...

# %%
# !yolo detect predict model = "/content/runs/detect/train/weights/best.pt" source="/content/Home Tour_Middle Class Home Tour_Organising Home_Sweet Home_House Tour.mp4"
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (8483/23599) /content/Home Tour_Middle Class Home Tour_Organising Home_Sweet Home_House Tour.mp4: 384x640 1 person, 14.1ms
# video 1/1 (8484/23599) /content/Home Tour_Middle Class Home Tour_Organising Home_Sweet Home_House Tour.mp4: 384x640 1 person, 7.7ms
# video 1/1 (8485/23599) /content/Home Tour_Middle Class Home Tour_Organising Home_Sweet Home_House Tour.mp4: 384x640 (no detections), 7.7ms
# video 1/1 (8486/23599) /content/Home Tour_Middle Class Home Tour_Organising Home_Sweet Home_House Tour.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (8487/23599) /content/Home Tour_Middle Class Home Tour_Organising Home_Sweet Home_House Tour.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (8488/23599) /content/Home Tour_Middle Class Home Tour_Organising Home_Sweet Home_House Tour.mp4: 384x640 1 person, 8.4ms
# ...

# %%
# !scp -r /content/runs/detect/predict3/మా కొత్త ఇంటి Utility Area ఇలా Set చేసా __ Madam Anthe __ Strikers.avi '/content/gdrive/MyDrive/Final_dataset'
# Out:
# cp: cannot stat '/content/runs/detect/predict3/మా': No such file or directory
# cp: cannot stat 'కొత్త': No such file or directory
# cp: cannot stat 'ఇంటి': No such file or directory
# cp: cannot stat 'Utility': No such file or directory
# cp: cannot stat 'Area': No such file or directory
# cp: cannot stat 'ఇలా': No such file or directory
# cp: cannot stat 'Set': No such file or directory
# cp: cannot stat 'చేసా': No such file or directory
# cp: cannot stat '__': No such file or directory
# cp: cannot stat 'Madam': No such file or directory
# cp: cannot stat 'Anthe': No such file or directory
# cp: cannot stat '__': No such file or directory
# cp: cannot stat 'Strikers.avi': No such file or directory

# %%
# !scp -r /content/runs/detect/predict4 '/content/gdrive/MyDrive/Final_dataset'
